# %% [markdown]
# # Programmatic Device Setup Construction
#
# The device setup object is used by LabOne Q to retrieve all information relating to the dataserver and the instruments connected to it from.
# Once complete, the device setup object exposes `LogicalSignals` and an interface to apply persistent `Calibration` changes to them or other calibratables contained in the device setup.
#
# In this notebook, you will learn how to define `DeviceSetup` objects for different instruments setups by using the recent programmatic construction functionality of LabOne Q.

# %% [markdown]
# ## Imports

# %% [markdown]
# LabOne Q standard imports

# %%
from laboneq.simple import *

# %% [markdown]
# We need to import the also the classes for the individual instrument models to build the device setup with and a helper function to create connections i.e. define logical signals
#
# Eventually, these imports will be included in `laboneq.simple` too...

# %%
from laboneq.dsl.device.instruments import SHFQC, SHFSG, SHFQA, HDAWG, UHFQA, PQSC
from laboneq.dsl.device import create_connection

# %% [markdown]
# ## Device Setup Initialization and Dataserver

# %% [markdown]
# We begin by initializing a mostly empty `DeviceSetup` instance

# %%
device_setup = DeviceSetup("my_setup_1")

# %% [markdown]
# The `add_dataserver` functionality allows to set the details of the connection to the dataserver.

# %%
device_setup.add_dataserver(host="111.22.33.44", port="8004")

# %% [markdown]
# Note, that this information can also be provided during the above initialization step.

# %% [markdown]
# ## Instruments

# %% [markdown]
# We can add individual instruments to the device setup

# %%
device_setup.add_instruments(SHFQC(uid="device_shfqc", address="dev12345"))
print(device_setup)
# Out:
# DeviceSetup(
# │   uid='my_setup_1',
# │   servers={
# │   │   'zi_server': DataServer(
# │   │   │   uid='zi_server',
# │   │   │   api_level=6,
# │   │   │   host='111.22.33.44',
# │   │   │   port='8004'
# │   │   )
# │   },
# │   instruments=[
# │   │   SHFQC(
# │   │   │   uid='device_shfqc',
# │   │   │   interface='1GbE',
# │   │   │   connections=[],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev12345',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0
# │   │   )
# │   ],
# │   physical_channel_groups={},
# │   logical_signal_groups={},
# │   qubits={}
# )

# %% [markdown]
# Note, that the resulting device setup has no physical channels defined yet.
#
# ## Connections
# We directly add a logical signal line in the form of `create_connection`

# %%
device_setup.add_connections(
    "device_shfqc",
    create_connection(to_signal="q0/drive_line", ports="SGCHANNELS/0/OUTPUT"),
)
print(device_setup)
# Out:
# DeviceSetup(
# │   uid='my_setup_1',
# │   servers={
# │   │   'zi_server': DataServer(
# │   │   │   uid='zi_server',
# │   │   │   api_level=6,
# │   │   │   host='111.22.33.44',
# │   │   │   port='8004'
# │   │   )
# │   },
# │   instruments=[
# │   │   SHFQC(
# │   │   │   uid='device_shfqc',
# │   │   │   interface='1GbE',
# │   │   │   connections=[
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   )
# │   │   │   ],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev12345',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0
# │   │   )
# │   ],
# │   physical_channel_groups={
# │   │   'device_shfqc': PhysicalChannelGroup(
# │   │   │   uid='device_shfqc',
# │   │   │   channels={
# │   │   │   │   'sgchannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   logical_signal_groups={
# │   │   'q0': LogicalSignalGroup(
# │   │   │   uid='q0',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q0/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   qubits={}
# )

# %% [markdown]
# Note, that a logical signal line as well as the connected physical channel were added to the device setup from this connection.
#
# ## Multiple Connections
# We can successively add additional connections

# %%
device_setup.add_connections(
    "device_shfqc",
    create_connection(to_signal="q1/drive_line", ports="SGCHANNELS/1/OUTPUT"),
)
print(device_setup)
# Out:
# DeviceSetup(
# │   uid='my_setup_1',
# │   servers={
# │   │   'zi_server': DataServer(
# │   │   │   uid='zi_server',
# │   │   │   api_level=6,
# │   │   │   host='111.22.33.44',
# │   │   │   port='8004'
# │   │   )
# │   },
# │   instruments=[
# │   │   SHFQC(
# │   │   │   uid='device_shfqc',
# │   │   │   interface='1GbE',
# │   │   │   connections=[
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/1/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   )
# │   │   │   ],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev12345',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0
# │   │   )
# │   ],
# │   physical_channel_groups={
# │   │   'device_shfqc': PhysicalChannelGroup(
# │   │   │   uid='device_shfqc',
# │   │   │   channels={
# │   │   │   │   'sgchannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_1_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   logical_signal_groups={
# │   │   'q0': LogicalSignalGroup(
# │   │   │   uid='q0',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q0/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q1': LogicalSignalGroup(
# │   │   │   uid='q1',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q1/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   qubits={}
# )

# %% [markdown]
# or add multiple connections at once

# %%
device_setup.add_connections(
    "device_shfqc",
    create_connection(to_signal="q0/measure_line", ports=["QACHANNELS/0/OUTPUT"]),
    create_connection(to_signal="q0/acquire_line", ports=["QACHANNELS/0/INPUT"]),
    create_connection(to_signal="q1/measure_line", ports=["QACHANNELS/0/OUTPUT"]),
    create_connection(to_signal="q1/acquire_line", ports=["QACHANNELS/0/INPUT"]),
)
print(device_setup)
# Out:
# DeviceSetup(
# │   uid='my_setup_1',
# │   servers={
# │   │   'zi_server': DataServer(
# │   │   │   uid='zi_server',
# │   │   │   api_level=6,
# │   │   │   host='111.22.33.44',
# │   │   │   port='8004'
# │   │   )
# │   },
# │   instruments=[
# │   │   SHFQC(
# │   │   │   uid='device_shfqc',
# │   │   │   interface='1GbE',
# │   │   │   connections=[
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/1/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   )
# │   │   │   ],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev12345',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0
# │   │   )
# │   ],
# │   physical_channel_groups={
# │   │   'device_shfqc': PhysicalChannelGroup(
# │   │   │   uid='device_shfqc',
# │   │   │   channels={
# │   │   │   │   'sgchannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_1_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'qachannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'qachannels_0_input': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   calibration=None
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   logical_signal_groups={
# │   │   'q0': LogicalSignalGroup(
# │   │   │   uid='q0',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q0/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q0/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q0/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q1': LogicalSignalGroup(
# │   │   │   uid='q1',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q1/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q1/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q1/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   qubits={}
# )

# %% [markdown]
# which allows for some programmatic constructions like.

# %%
inds = [2, 3]
device_setup.add_connections(
    "device_shfqc",
    *[
        create_connection(
            to_signal=f"q{_}/drive_line", ports=[f"SGCHANNELS/{_}/OUTPUT"]
        )
        for _ in inds
    ],
    *[
        create_connection(to_signal=f"q{_}/measure_line", ports=["QACHANNELS/0/OUTPUT"])
        for _ in inds
    ],
    *[
        create_connection(to_signal=f"q{_}/acquire_line", ports=["QACHANNELS/0/INPUT"])
        for _ in inds
    ],
)
print(device_setup)
# Out:
# DeviceSetup(
# │   uid='my_setup_1',
# │   servers={
# │   │   'zi_server': DataServer(
# │   │   │   uid='zi_server',
# │   │   │   api_level=6,
# │   │   │   host='111.22.33.44',
# │   │   │   port='8004'
# │   │   )
# │   },
# │   instruments=[
# │   │   SHFQC(
# │   │   │   uid='device_shfqc',
# │   │   │   interface='1GbE',
# │   │   │   connections=[
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/1/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/2/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/3/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   )
# │   │   │   ],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev12345',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0
# │   │   )
# │   ],
# │   physical_channel_groups={
# │   │   'device_shfqc': PhysicalChannelGroup(
# │   │   │   uid='device_shfqc',
# │   │   │   channels={
# │   │   │   │   'sgchannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_1_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'qachannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'qachannels_0_input': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_2_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_2_output',
# │   │   │   │   │   name='sgchannels_2_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_2_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_3_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_3_output',
# │   │   │   │   │   name='sgchannels_3_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_3_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   logical_signal_groups={
# │   │   'q0': LogicalSignalGroup(
# │   │   │   uid='q0',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q0/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q0/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q0/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q1': LogicalSignalGroup(
# │   │   │   uid='q1',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q1/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q1/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q1/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q2': LogicalSignalGroup(
# │   │   │   uid='q2',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q2/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_2_output',
# │   │   │   │   │   │   name='sgchannels_2_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_2_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q2/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q2/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q3': LogicalSignalGroup(
# │   │   │   uid='q3',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q3/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_3_output',
# │   │   │   │   │   │   name='sgchannels_3_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_3_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q3/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q3/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   qubits={}
# )

# %% [markdown]
# connections can only be added if they do not exist already

# %%
try:
    device_setup.add_connections(
        "device_shfqc",
        create_connection(to_signal="q0/drive_line", ports="SGCHANNELS/0/OUTPUT"),
    )
except:
    print("LabOneQException as expected")
# Out:
# LabOneQException as expected

# %% [markdown]
# ## Setups with Multiple Instruments
# We want to add another instrument and define logical signal lines from its ports.
# Here, we add a HDAWG to the setup as well as a PQSC.

# %%
device_setup.add_instruments(
    HDAWG(uid="device_hdawg", address="dev8765"),
    PQSC(uid="device_pqsc", address="dev10123"),
)

# %% [markdown]
# The PQSC uses ZSYNC connections to synchronize between the SHFQC and the HDAWG.
# We can use the `add_connections` method to define also ZSYNC connectivity between instruments.

# %%
device_setup.add_connections(
    "device_pqsc",
    create_connection(to_instrument="device_shfqc", ports="ZSYNCS/0"),
    create_connection(to_instrument="device_hdawg", ports="ZSYNCS/10"),
)
print(device_setup)
# Out:
# DeviceSetup(
# │   uid='my_setup_1',
# │   servers={
# │   │   'zi_server': DataServer(
# │   │   │   uid='zi_server',
# │   │   │   api_level=6,
# │   │   │   host='111.22.33.44',
# │   │   │   port='8004'
# │   │   )
# │   },
# │   instruments=[
# │   │   SHFQC(
# │   │   │   uid='device_shfqc',
# │   │   │   interface='1GbE',
# │   │   │   connections=[
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/1/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/2/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/3/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   )
# │   │   │   ],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev12345',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0
# │   │   ),
# │   │   HDAWG(
# │   │   │   uid='device_hdawg',
# │   │   │   interface='1GbE',
# │   │   │   connections=[],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev8765',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0
# │   │   ),
# │   │   PQSC(
# │   │   │   uid='device_pqsc',
# │   │   │   interface='1GbE',
# │   │   │   connections=[
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='ZSYNCS/0',
# │   │   │   │   │   remote_path='device_shfqc',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.ZSYNC
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='ZSYNCS/10',
# │   │   │   │   │   remote_path='device_hdawg',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.ZSYNC
# │   │   │   │   )
# │   │   │   ],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev10123',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0,
# │   │   │   reference_clock=10000000.0
# │   │   )
# │   ],
# │   physical_channel_groups={
# │   │   'device_shfqc': PhysicalChannelGroup(
# │   │   │   uid='device_shfqc',
# │   │   │   channels={
# │   │   │   │   'sgchannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_1_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'qachannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'qachannels_0_input': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_2_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_2_output',
# │   │   │   │   │   name='sgchannels_2_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_2_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_3_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_3_output',
# │   │   │   │   │   name='sgchannels_3_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_3_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   logical_signal_groups={
# │   │   'q0': LogicalSignalGroup(
# │   │   │   uid='q0',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q0/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q0/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q0/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q1': LogicalSignalGroup(
# │   │   │   uid='q1',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q1/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q1/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q1/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q2': LogicalSignalGroup(
# │   │   │   uid='q2',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q2/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_2_output',
# │   │   │   │   │   │   name='sgchannels_2_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_2_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q2/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q2/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q3': LogicalSignalGroup(
# │   │   │   uid='q3',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q3/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_3_output',
# │   │   │   │   │   │   name='sgchannels_3_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_3_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q3/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q3/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   qubits={}
# )

# %% [markdown]
# Finally, we define the additional `LogicalSignal` lines on the HDAWG

# %%
device_setup.add_connections(
    "device_hdawg",
    *[
        create_connection(to_signal=f"q{_}/flux_line", ports=f"SIGOUTS/{_}")
        for _ in range(4)
    ],
)
print(device_setup)
# Out:
# DeviceSetup(
# │   uid='my_setup_1',
# │   servers={
# │   │   'zi_server': DataServer(
# │   │   │   uid='zi_server',
# │   │   │   api_level=6,
# │   │   │   host='111.22.33.44',
# │   │   │   port='8004'
# │   │   )
# │   },
# │   instruments=[
# │   │   SHFQC(
# │   │   │   uid='device_shfqc',
# │   │   │   interface='1GbE',
# │   │   │   connections=[
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/1/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/2/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SGCHANNELS/3/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/drive_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/OUTPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/measure_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.IN,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='QACHANNELS/0/INPUT',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/acquire_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.IQ
# │   │   │   │   )
# │   │   │   ],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev12345',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0
# │   │   ),
# │   │   HDAWG(
# │   │   │   uid='device_hdawg',
# │   │   │   interface='1GbE',
# │   │   │   connections=[
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SIGOUTS/0',
# │   │   │   │   │   remote_path='/logical_signal_groups/q0/flux_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.RF
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SIGOUTS/1',
# │   │   │   │   │   remote_path='/logical_signal_groups/q1/flux_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.RF
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SIGOUTS/2',
# │   │   │   │   │   remote_path='/logical_signal_groups/q2/flux_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.RF
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='SIGOUTS/3',
# │   │   │   │   │   remote_path='/logical_signal_groups/q3/flux_line',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.RF
# │   │   │   │   )
# │   │   │   ],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev8765',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0
# │   │   ),
# │   │   PQSC(
# │   │   │   uid='device_pqsc',
# │   │   │   interface='1GbE',
# │   │   │   connections=[
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='ZSYNCS/0',
# │   │   │   │   │   remote_path='device_shfqc',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.ZSYNC
# │   │   │   │   ),
# │   │   │   │   Connection(
# │   │   │   │   │   direction=IODirection.OUT,
# │   │   │   │   │   local_path=None,
# │   │   │   │   │   local_port='ZSYNCS/10',
# │   │   │   │   │   remote_path='device_hdawg',
# │   │   │   │   │   remote_port='0',
# │   │   │   │   │   signal_type=IOSignalType.ZSYNC
# │   │   │   │   )
# │   │   │   ],
# │   │   │   server_uid='zi_server',
# │   │   │   address='dev10123',
# │   │   │   device_options=None,
# │   │   │   reference_clock_source=None,
# │   │   │   device_class=0,
# │   │   │   reference_clock=10000000.0
# │   │   )
# │   ],
# │   physical_channel_groups={
# │   │   'device_shfqc': PhysicalChannelGroup(
# │   │   │   uid='device_shfqc',
# │   │   │   channels={
# │   │   │   │   'sgchannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_1_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'qachannels_0_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'qachannels_0_input': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_2_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_2_output',
# │   │   │   │   │   name='sgchannels_2_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_2_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sgchannels_3_output': PhysicalChannel(
# │   │   │   │   │   uid='device_shfqc/sgchannels_3_output',
# │   │   │   │   │   name='sgchannels_3_output',
# │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_3_output',
# │   │   │   │   │   calibration=None
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'device_hdawg': PhysicalChannelGroup(
# │   │   │   uid='device_hdawg',
# │   │   │   channels={
# │   │   │   │   'sigouts_0': PhysicalChannel(
# │   │   │   │   │   uid='device_hdawg/sigouts_0',
# │   │   │   │   │   name='sigouts_0',
# │   │   │   │   │   type=<PhysicalChannelType.RF_CHANNEL: 'rf_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_hdawg/sigouts_0',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sigouts_1': PhysicalChannel(
# │   │   │   │   │   uid='device_hdawg/sigouts_1',
# │   │   │   │   │   name='sigouts_1',
# │   │   │   │   │   type=<PhysicalChannelType.RF_CHANNEL: 'rf_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_hdawg/sigouts_1',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sigouts_2': PhysicalChannel(
# │   │   │   │   │   uid='device_hdawg/sigouts_2',
# │   │   │   │   │   name='sigouts_2',
# │   │   │   │   │   type=<PhysicalChannelType.RF_CHANNEL: 'rf_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_hdawg/sigouts_2',
# │   │   │   │   │   calibration=None
# │   │   │   │   ),
# │   │   │   │   'sigouts_3': PhysicalChannel(
# │   │   │   │   │   uid='device_hdawg/sigouts_3',
# │   │   │   │   │   name='sigouts_3',
# │   │   │   │   │   type=<PhysicalChannelType.RF_CHANNEL: 'rf_channel'>,
# │   │   │   │   │   path='/physical_channel_groups/device_hdawg/sigouts_3',
# │   │   │   │   │   calibration=None
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   logical_signal_groups={
# │   │   'q0': LogicalSignalGroup(
# │   │   │   uid='q0',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q0/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   name='sgchannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q0/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q0/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   ),
# │   │   │   │   'flux_line': LogicalSignal(
# │   │   │   │   │   uid='q0/flux_line',
# │   │   │   │   │   name='flux_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_hdawg/sigouts_0',
# │   │   │   │   │   │   name='sigouts_0',
# │   │   │   │   │   │   type=<PhysicalChannelType.RF_CHANNEL: 'rf_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_hdawg/sigouts_0',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q0/flux_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q1': LogicalSignalGroup(
# │   │   │   uid='q1',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q1/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   name='sgchannels_1_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_1_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q1/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q1/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   ),
# │   │   │   │   'flux_line': LogicalSignal(
# │   │   │   │   │   uid='q1/flux_line',
# │   │   │   │   │   name='flux_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_hdawg/sigouts_1',
# │   │   │   │   │   │   name='sigouts_1',
# │   │   │   │   │   │   type=<PhysicalChannelType.RF_CHANNEL: 'rf_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_hdawg/sigouts_1',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q1/flux_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q2': LogicalSignalGroup(
# │   │   │   uid='q2',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q2/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_2_output',
# │   │   │   │   │   │   name='sgchannels_2_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_2_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q2/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q2/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   ),
# │   │   │   │   'flux_line': LogicalSignal(
# │   │   │   │   │   uid='q2/flux_line',
# │   │   │   │   │   name='flux_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_hdawg/sigouts_2',
# │   │   │   │   │   │   name='sigouts_2',
# │   │   │   │   │   │   type=<PhysicalChannelType.RF_CHANNEL: 'rf_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_hdawg/sigouts_2',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q2/flux_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   )
# │   │   │   }
# │   │   ),
# │   │   'q3': LogicalSignalGroup(
# │   │   │   uid='q3',
# │   │   │   logical_signals={
# │   │   │   │   'drive_line': LogicalSignal(
# │   │   │   │   │   uid='q3/drive_line',
# │   │   │   │   │   name='drive_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/sgchannels_3_output',
# │   │   │   │   │   │   name='sgchannels_3_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/sgchannels_3_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/drive_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'measure_line': LogicalSignal(
# │   │   │   │   │   uid='q3/measure_line',
# │   │   │   │   │   name='measure_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   name='qachannels_0_output',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_output',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/measure_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   ),
# │   │   │   │   'acquire_line': LogicalSignal(
# │   │   │   │   │   uid='q3/acquire_line',
# │   │   │   │   │   name='acquire_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   name='qachannels_0_input',
# │   │   │   │   │   │   type=<PhysicalChannelType.IQ_CHANNEL: 'iq_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_shfqc/qachannels_0_input',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/acquire_line',
# │   │   │   │   │   direction=IODirection.IN
# │   │   │   │   ),
# │   │   │   │   'flux_line': LogicalSignal(
# │   │   │   │   │   uid='q3/flux_line',
# │   │   │   │   │   name='flux_line',
# │   │   │   │   │   calibration=None,
# │   │   │   │   │   physical_channel=PhysicalChannel(
# │   │   │   │   │   │   uid='device_hdawg/sigouts_3',
# │   │   │   │   │   │   name='sigouts_3',
# │   │   │   │   │   │   type=<PhysicalChannelType.RF_CHANNEL: 'rf_channel'>,
# │   │   │   │   │   │   path='/physical_channel_groups/device_hdawg/sigouts_3',
# │   │   │   │   │   │   calibration=None
# │   │   │   │   │   ),
# │   │   │   │   │   path='/logical_signal_groups/q3/flux_line',
# │   │   │   │   │   direction=IODirection.OUT
# │   │   │   │   )
# │   │   │   }
# │   │   )
# │   },
# │   qubits={}
# )

# %% [markdown]
# ## Device Setup at Scale
# We can combine the above methods to define large scale device setups programmatically.

# %%
scaled_setup = DeviceSetup("my_scaled_setup")
scaled_setup.add_dataserver(host="111.22.33.44", port="8004")
scaled_setup.add_instruments(PQSC(uid="pqsc", address="dev10001"))

# %% [markdown]
# Add drive line signals using an SHFSG for each eight qubits

# %%
for i in range(8):
    scaled_setup.add_instruments(SHFSG(uid=f"shfsg_{i}", address=f"dev1212{i}"))
    scaled_setup.add_connections(
        "pqsc", create_connection(to_instrument=f"shfsg_{i}", ports=f"ZSYNCS/{i}")
    )
    scaled_setup.add_connections(
        f"shfsg_{i}",
        *[
            create_connection(
                to_signal=f"q{i*8+_}/drive_line", ports=f"SGCHANNELS/{_}/OUTPUT"
            )
            for _ in range(8)
        ],
    )

# %% [markdown]
# Likewise, add flux line signals using an HDAWG for eight qubits

# %%
for i in range(8):
    scaled_setup.add_instruments(HDAWG(uid=f"hdawg_{i}", address=f"dev876{i}"))
    scaled_setup.add_connections(
        "pqsc", create_connection(to_instrument=f"hdawg_{i}", ports=f"ZSYNCS/{i+8}")
    )
    scaled_setup.add_connections(
        f"hdawg_{i}",
        *[
            create_connection(to_signal=f"q{i*8+_}/flux_line", ports=f"SIGOUTS/{_}")
            for _ in range(8)
        ],
    )

# %% [markdown]
# Define pairs of measure and acquire signals together, 8 qubits per QA unit with 4 QA units per SHFQA

# %%
for i in range(2):
    scaled_setup.add_instruments(SHFQA(uid=f"shfqa_{i}", address=f"dev1234{i}"))
    scaled_setup.add_connections(
        "pqsc", create_connection(to_instrument=f"shfqa_{i}", ports=f"ZSYNCS/{i+16}")
    )
    for j in range(4):
        scaled_setup.add_connections(
            f"shfqa_{i}",
            *[
                create_connection(
                    to_signal=f"q{i*32+j*8+_}/measure_line",
                    ports=f"QACHANNELS/{j}/OUTPUT",
                )
                for _ in range(8)
            ],
            *[
                create_connection(
                    to_signal=f"q{i*32+j*8+_}/acquire_line",
                    ports=f"QACHANNELS/{j}/INPUT",
                )
                for _ in range(8)
            ],
        )

# %% [markdown]
# We verify that we have defined the logical signal lines q0 to q63, each with a drive, flux, measure, and acquire line, respectively.

# %%
for lsg in scaled_setup.logical_signal_groups:
    print(lsg, *scaled_setup.logical_signal_groups[lsg].logical_signals.keys())
# Out:
# q0 drive_line flux_line measure_line acquire_line
# q1 drive_line flux_line measure_line acquire_line
# q2 drive_line flux_line measure_line acquire_line
# q3 drive_line flux_line measure_line acquire_line
# q4 drive_line flux_line measure_line acquire_line
# q5 drive_line flux_line measure_line acquire_line
# q6 drive_line flux_line measure_line acquire_line
# q7 drive_line flux_line measure_line acquire_line
# q8 drive_line flux_line measure_line acquire_line
# q9 drive_line flux_line measure_line acquire_line
# q10 drive_line flux_line measure_line acquire_line
# q11 drive_line flux_line measure_line acquire_line
# q12 drive_line flux_line measure_line acquire_line
# q13 drive_line flux_line measure_line acquire_line
# q14 drive_line flux_line measure_line acquire_line
# q15 drive_line flux_line measure_line acquire_line
# q16 drive_line flux_line measure_line acquire_line
# q17 drive_line flux_line measure_line acquire_line
# q18 drive_line flux_line measure_line acquire_line
# q19 drive_line flux_line measure_line acquire_line
# q20 drive_line flux_line measure_line acquire_line
# q21 drive_line flux_line measure_line acquire_line
# q22 drive_line flux_line measure_line acquire_line
# q23 drive_line flux_line measure_line acquire_line
# q24 drive_line flux_line measure_line acquire_line
# q25 drive_line flux_line measure_line acquire_line
# q26 drive_line flux_line measure_line acquire_line
# q27 drive_line flux_line measure_line acquire_line
# q28 drive_line flux_line measure_line acquire_line
# q29 drive_line flux_line measure_line acquire_line
# q30 drive_line flux_line measure_line acquire_line
# q31 drive_line flux_line measure_line acquire_line
# q32 drive_line flux_line measure_line acquire_line
# q33 drive_line flux_line measure_line acquire_line
# q34 drive_line flux_line measure_line acquire_line
# q35 drive_line flux_line measure_line acquire_line
# q36 drive_line flux_line measure_line acquire_line
# q37 drive_line flux_line measure_line acquire_line
# q38 drive_line flux_line measure_line acquire_line
# q39 drive_line flux_line measure_line acquire_line
# q40 drive_line flux_line measure_line acquire_line
# q41 drive_line flux_line measure_line acquire_line
# q42 drive_line flux_line measure_line acquire_line
# q43 drive_line flux_line measure_line acquire_line
# q44 drive_line flux_line measure_line acquire_line
# q45 drive_line flux_line measure_line acquire_line
# q46 drive_line flux_line measure_line acquire_line
# q47 drive_line flux_line measure_line acquire_line
# q48 drive_line flux_line measure_line acquire_line
# q49 drive_line flux_line measure_line acquire_line
# q50 drive_line flux_line measure_line acquire_line
# q51 drive_line flux_line measure_line acquire_line
# q52 drive_line flux_line measure_line acquire_line
# q53 drive_line flux_line measure_line acquire_line
# q54 drive_line flux_line measure_line acquire_line
# q55 drive_line flux_line measure_line acquire_line
# q56 drive_line flux_line measure_line acquire_line
# q57 drive_line flux_line measure_line acquire_line
# q58 drive_line flux_line measure_line acquire_line
# q59 drive_line flux_line measure_line acquire_line
# q60 drive_line flux_line measure_line acquire_line
# q61 drive_line flux_line measure_line acquire_line
# q62 drive_line flux_line measure_line acquire_line
# q63 drive_line flux_line measure_line acquire_line

# %% [markdown]
# Note
# * Significantly higher qubit counts are only possible using a QHUB for synchronization
# * The above example assumes regularity in the wiring. Functionality to readapt existing connections e.g. to swap out two experimental lines, is not yet implemented.
# * The index logic in the above can be simplified further.

# %% [markdown]
# ## Setups with Gen1 Instruments

# %% [markdown]
# The definition of sets of gen1 instruments is done also with the above methods.

# %%
gen1_setup = DeviceSetup("gen1_qzilla")
gen1_setup.add_dataserver(host="111.22.33.44", port="8004")
gen1_setup.add_instruments(
    HDAWG(uid="hdawg", address="dev8768"),
    UHFQA(uid="uhfqa", address="dev2890"),
    PQSC(uid="pqsc", address="dev10001"),
)

# %% [markdown]
# We need, however to account the different connections between the instruments.
# Specifically, in such setups only the HDAWG has a ZSYNC connection to the PQSC,

# %%
gen1_setup.add_connections(
    "pqsc", create_connection(to_instrument="hdawg", ports="ZSYNCS/0")
)

# %% [markdown]
# while the UHFQA instrument connects to the HDAWG via a DIOS port.

# %%
gen1_setup.add_connections(
    "hdawg", create_connection(to_instrument="device_uhfqa", ports="DIOS/0")
)

# %% [markdown]
# Furthermore, in such setup the I and Q signal components of the same logical signal are located at different physical ports.
# We account for this by handing a list of both physical ports to the ports argument.

# %%
gen1_setup.add_connections(
    "hdawg",
    create_connection(to_signal="q0/drive_line", ports=["SIGOUTS/0", "SIGOUTS/1"]),
)
gen1_setup.add_connections(
    "uhfqa",
    create_connection(to_signal="q0/acquire_line", ports=["SIGOUTS/0", "SIGOUTS/1"]),
)
